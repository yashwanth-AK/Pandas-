# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %% [markdown]
# #this is a sample with getting started to machine learning.

# %%
df=pd.read_csv("Swiggy_50.csv",index_col=0)

# %%
df
# Out:
#                           Restaurant Name  \
# 0                                     KFC
# 1                              McDonald's
# 2                              Haldiram's
# 3                              Chai Point
# 4               Bikanervala Chandni Chowk
# ...                                   ...
# 31799  Khukri Desi Mutton & Chicken Point
# 31800                    Monis Restaurant
# 31801                T3 Tasty Table Talks
# 31802                     The Green Lemon
# 31803                     Pizza Home City
#
#                                                 Category  Rating  \
# 0                                American,Snacks,Biryani     3.9
# 1                                               American     4.3
# 2                             Sweets,Snacks,North Indian     4.0
# 3      Bakery,Beverages,Maharashtrian,Snacks,Street F...     4.2
# 4                                     Street Food,Sweets     4.1
# ...

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Category', 'Rating', 'Cost for two', 'Veg', 'city',
#        'Area', 'Locality', 'Address', 'Long Distance Delivery'],
#       dtype='object')

# %%
df.Veg
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 31799    False
# 31800     True
# 31801     True
# 31802    False
# 31803     True
# Name: Veg, Length: 31804, dtype: bool

# %%
df.dtypes
# Out:
# Category                   object
# Rating                    float64
# Cost for two                int64
# Veg                          bool
# city                       object
# Area                       object
# Locality                   object
# Address                    object
# Long Distance Delivery      int64
# dtype: object

# %% [markdown]
# # Getting started with functions in pandas.

# %%
#here we'll see some ways to describe the data.
#dtypes
#columns.
#index=returns the range value were it starts and ends.
#describe
#info
#mean
#sum.


df.describe()
# Out:
#              Rating  Cost for two  Long Distance Delivery
# count  14138.000000  31804.000000            31804.000000
# mean       3.907745    289.795592                0.358414
# std        0.456514    174.896346                0.479542
# min        1.100000      0.000000                0.000000
# 25%        3.700000    200.000000                0.000000
# 50%        4.000000    250.000000                0.000000
# 75%        4.200000    300.000000                1.000000
# max        5.000000   3100.000000                1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31804 entries, KFC to Pizza Home City
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                31804 non-null  object
#  1   Rating                  14138 non-null  float64
#  2   Cost for two            31804 non-null  int64
#  3   Veg                     31804 non-null  bool
#  4   city                    31804 non-null  object
#  5   Area                    31804 non-null  object
#  6   Locality                31780 non-null  object
#  7   Address                 31802 non-null  object
#  8   Long Distance Delivery  31804 non-null  int64
# dtypes: bool(1), float64(1), int64(2), object(5)
# memory usage: 2.2+ MB

# %%
df.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6156\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Rating                      3.907745
# Cost for two              289.795592
# Veg                         0.275123
# Long Distance Delivery      0.358414
# dtype: float64

# %%
df.sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6156\1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Category                  American,Snacks,BiryaniAmericanSweets,Snacks,N...
# Rating                                                              55247.7
# Cost for two                                                        9216659
# Veg                                                                    8750
# city                      DelhiDelhiDelhiDelhiDelhiDelhiDelhiDelhiDelhiD...
# Area                      PaharganjKashmere GateChandni ChowkConnaught P...
# Long Distance Delivery                                                11399
# dtype: object

# %%
df.head()
# Out:
#                                                                     Category  \
# Restaurant Name
# KFC                                                  American,Snacks,Biryani
# McDonald's                                                          American
# Haldiram's                                        Sweets,Snacks,North Indian
# Chai Point                 Bakery,Beverages,Maharashtrian,Snacks,Street F...
# Bikanervala Chandni Chowk                                 Street Food,Sweets
#
#                            Rating  Cost for two    Veg   city  \
# Restaurant Name
# KFC                           3.9           400  False  Delhi
# McDonald's                    4.3           400  False  Delhi
# Haldiram's                    4.0           350   True  Delhi
# Chai Point                    4.2           150  False  Delhi
# Bikanervala Chandni Chowk     4.1           400  False  Delhi
#
#                                       Area              Locality  \
# Restaurant Name
# ...

# %% [markdown]
# # Different ways of viewing Data in Pandas.

# %%
#here in this i tried some functions to viewing data.
#head()
#tail()
#loc()
#iloc()
df.tail()
# Out:
#                                                                              Category  \
# Restaurant Name
# Khukri Desi Mutton & Chicken Point                           Indian,Biryani,Beverages
# Monis Restaurant                    South Indian,Chinese,Snacks,Desserts,North Indian
# T3 Tasty Table Talks                                                    Indian,Thalis
# The Green Lemon                                                                Indian
# Pizza Home City                       Pizzas,Beverages,Pastas,Italian,Desserts,Snacks
#
#                                     Rating  Cost for two    Veg      city  \
# Restaurant Name
# Khukri Desi Mutton & Chicken Point     NaN           300  False  Bareilly
# Monis Restaurant                       NaN           250   True  Bareilly
# T3 Tasty Table Talks                   NaN           200   True  Bareilly
# The Green Lemon                        NaN           400  False  Bareilly
# ...

# %%
df.loc[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\desktop\sample_project_1\env\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\desktop\sample_project_1\env\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\desktop\sample_project_1\env\lib\site-packages\pandas\_libs\index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\desktop\sample_project_1\env\lib\site-packages\pandas\_libs\index.pyx:201, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\desktop\sample_project_1\env\lib\site-packages\pandas\_libs\index.pyx:209, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
|
